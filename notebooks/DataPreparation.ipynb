# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import os

# %%
# read raw dataset
df = pd.read_csv('../data/archive/amazon_reviews_us_Electronics_v1_00.tsv', sep='\t', on_bad_lines='skip')
df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     41409413  R2MTG1GCZLR2DK  B00428R89M       112201306
# 1          US     49668221  R2HBOEM8LE9928  B000068O48       734576678
# 2          US     12338275  R1P4RW1R9FDPEE  B000GGKOG8       614448099
# 3          US     38487968  R1EBPM82ENI67M  B000NU4OTA        72265257
# 4          US     23732619  R372S58V6D11AT  B00JOQIO6S       308169188
#
#                                        product_title product_category  \
# 0  yoomall 5M Antenna WIFI RP-SMA Female to Male ...      Electronics
# 1         Hosa GPM-103 3.5mm TRS to 1/4" TRS Adaptor      Electronics
# 2        Channel Master Titan 2 Antenna Preamplifier      Electronics
# 3  LIMTECH Wall charger + USB Hotsync & Charging ...      Electronics
# 4     Skullcandy Air Raid Portable Bluetooth Speaker      Electronics
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            5              0            0    N                 Y
# 1            5              0            0    N                 Y
# 2            5              1            1    N                 Y
# 3            1              0            0    N                 Y
# 4            5              1            1    N                 Y
#
#                  review_headline  \
# 0                     Five Stars
# 1       It works as advertising.
# 2                     Five Stars
# 3                       One Star
# 4  Overall pleased with the item
#
#                                          review_body review_date
# 0                                      As described.  2015-08-31
# 1                           It works as advertising.  2015-08-31
# 2                                        Works pissa  2015-08-31
# 3                               Did not work at all.  2015-08-31
# 4  Works well. Bass is somewhat lacking but is pr...  2015-08-31

# %% [markdown]
# # Data selection
#
# In this section we will focus on what data is relevant for us

# %%
# get all columns names
df.columns
# Out:
# Index(['marketplace', 'customer_id', 'review_id', 'product_id',
#        'product_parent', 'product_title', 'product_category', 'star_rating',
#        'helpful_votes', 'total_votes', 'vine', 'verified_purchase',
#        'review_headline', 'review_body', 'review_date'],
#       dtype='object')

# %% [markdown]
# Let's discuss a bit why some columns could be considered irrelevant and why. The solution is model-dependent as would influence how further algorithm is developed, so let's focus on both currently available recommendation-system designs.
#
# **Personalized recommendation system**\
# In context of personalized recommendations (unique for each user) we only need to store rating user gave, and to what product is was given to, resulting in tuple `customer_id`, `product_id` and `star_rating`. However, to make this data more appropricate and actually suitable for models, we should clear it from outliers, make some assumptions about 'usefullness' and 'acutality' of reviews given. For that reason it would make sence to store all columns that could be used as filteres in next steps.
#
# According to [Data Understanding](https://github.com/akmchnkv/Amazon-Predictions-Data-Mining-Innopolis-2024/blob/main/notebooks/EDA.ipynb), we can say that columns `marketplace`, `product_category` could be removed entirely as they only contain 1 unique value throuout all the rows. In addition, we can also disgard `vine` due to huge class disbalance (can't filter by vine=1, and vine=0 as it would chande distributions).
#
# In given architecture we also decided not to use `product_title` as it could not be used as filter due to it's variability and 'text'-nature.
#
# **Generalized recommendation system**\
# In the context of universal recommendations we can use almost all values that describe product. We can use text embeddings, star ratings, even headlines and dates as a features to develop a model. The only features we would disgard in this case are `marketplace`, `product_category` for the same reasons mentioned before.
#
# Currently we will prepare data only for **Personalized recommendation systems** as they correlate more with our business objective, however with a few changes (add 1 columns) we can make dataset for **Generalized recommendation systems**.

# %%
drop_personalized_columns = ['marketplace', 'product_category', 'vine']
drop_generalized_columns = ['marketplace', 'product_category']

# %% [markdown]
# # Data cleaning

# %%
# check how many NaN values each columns contain (in %, 100 = all none)
df.isna().sum() * 100 / df.shape[0]
# Out:
# marketplace          0.000000
# customer_id          0.000000
# review_id            0.000000
# product_id           0.000000
# product_parent       0.000000
# product_title        0.000129
# product_category     0.000000
# star_rating          0.000000
# helpful_votes        0.000000
# total_votes          0.000000
# vine                 0.000000
# verified_purchase    0.000000
# review_headline      0.001262
# review_body          0.004756
# review_date          0.000776
# dtype: float64

# %%
# As there are few rows (less than 0.005%) that actually contain NaN values, we can just drop them
df = df.dropna()
df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     41409413  R2MTG1GCZLR2DK  B00428R89M       112201306
# 1          US     49668221  R2HBOEM8LE9928  B000068O48       734576678
# 2          US     12338275  R1P4RW1R9FDPEE  B000GGKOG8       614448099
# 3          US     38487968  R1EBPM82ENI67M  B000NU4OTA        72265257
# 4          US     23732619  R372S58V6D11AT  B00JOQIO6S       308169188
#
#                                        product_title product_category  \
# 0  yoomall 5M Antenna WIFI RP-SMA Female to Male ...      Electronics
# 1         Hosa GPM-103 3.5mm TRS to 1/4" TRS Adaptor      Electronics
# 2        Channel Master Titan 2 Antenna Preamplifier      Electronics
# 3  LIMTECH Wall charger + USB Hotsync & Charging ...      Electronics
# 4     Skullcandy Air Raid Portable Bluetooth Speaker      Electronics
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            5              0            0    N                 Y
# 1            5              0            0    N                 Y
# 2            5              1            1    N                 Y
# 3            1              0            0    N                 Y
# 4            5              1            1    N                 Y
#
#                  review_headline  \
# 0                     Five Stars
# 1       It works as advertising.
# 2                     Five Stars
# 3                       One Star
# 4  Overall pleased with the item
#
#                                          review_body review_date
# 0                                      As described.  2015-08-31
# 1                           It works as advertising.  2015-08-31
# 2                                        Works pissa  2015-08-31
# 3                               Did not work at all.  2015-08-31
# 4  Works well. Bass is somewhat lacking but is pr...  2015-08-31

# %% [markdown]
# # Data construction
#
# In data construction step we will develop some features that may (or may not) be considered usefull in data modeling and future data preparations steps.
# 1. `helpfulness` - how many (in %) people consider given review helpfull.
# 2. `review_full_text` - combined `review_healine` and `review_body` for consistency (people are inconsistent and sometimes write review in headline, not in body)
# 3. `review_length` - total length of review headline and body (+1)

# %%
# percentage of people who considered review helpful
df['helpfulness'] = df['helpful_votes'] / df['total_votes']
df['helpfulness'] = df.helpfulness.fillna(0)

# full review text 
df["review_full_text"] = df["review_headline"] + " " + df["review_body"]

# length of review (number of symbols)
df['review_length'] = df.review_full_text.str.len()

df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     41409413  R2MTG1GCZLR2DK  B00428R89M       112201306
# 1          US     49668221  R2HBOEM8LE9928  B000068O48       734576678
# 2          US     12338275  R1P4RW1R9FDPEE  B000GGKOG8       614448099
# 3          US     38487968  R1EBPM82ENI67M  B000NU4OTA        72265257
# 4          US     23732619  R372S58V6D11AT  B00JOQIO6S       308169188
#
#                                        product_title product_category  \
# 0  yoomall 5M Antenna WIFI RP-SMA Female to Male ...      Electronics
# 1         Hosa GPM-103 3.5mm TRS to 1/4" TRS Adaptor      Electronics
# 2        Channel Master Titan 2 Antenna Preamplifier      Electronics
# 3  LIMTECH Wall charger + USB Hotsync & Charging ...      Electronics
# 4     Skullcandy Air Raid Portable Bluetooth Speaker      Electronics
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            5              0            0    N                 Y
# 1            5              0            0    N                 Y
# 2            5              1            1    N                 Y
# 3            1              0            0    N                 Y
# 4            5              1            1    N                 Y
#
#                  review_headline  \
# 0                     Five Stars
# 1       It works as advertising.
# 2                     Five Stars
# 3                       One Star
# 4  Overall pleased with the item
#
#                                          review_body review_date  helpfulness  \
# 0                                      As described.  2015-08-31          0.0
# 1                           It works as advertising.  2015-08-31          0.0
# 2                                        Works pissa  2015-08-31          1.0
# 3                               Did not work at all.  2015-08-31          0.0
# 4  Works well. Bass is somewhat lacking but is pr...  2015-08-31          1.0
#
#                                     review_full_text  review_length
# 0                           Five Stars As described.             24
# 1  It works as advertising. It works as advertising.             49
# 2                             Five Stars Works pissa             22
# 3                      One Star Did not work at all.             29
# 4  Overall pleased with the item Works well. Bass...            113

# %% [markdown]
# # Data formating & integration
#
# In this section we will be focusing on formating and filtering data, as well as getting additional information into a dataset.
# This sections are usually considered differently, however for a reason of reasonable resource management we will do them at the same time.
#
# We propose 3 different solutions to data formatting, and one of it requires additional data integration.

# %%
# get personalized recommentations (proposed in data selection)
df_personalized = df.drop(columns=drop_personalized_columns)
df_personalized.head()
# Out:
#    customer_id       review_id  product_id  product_parent  \
# 0     41409413  R2MTG1GCZLR2DK  B00428R89M       112201306
# 1     49668221  R2HBOEM8LE9928  B000068O48       734576678
# 2     12338275  R1P4RW1R9FDPEE  B000GGKOG8       614448099
# 3     38487968  R1EBPM82ENI67M  B000NU4OTA        72265257
# 4     23732619  R372S58V6D11AT  B00JOQIO6S       308169188
#
#                                        product_title  star_rating  \
# 0  yoomall 5M Antenna WIFI RP-SMA Female to Male ...            5
# 1         Hosa GPM-103 3.5mm TRS to 1/4" TRS Adaptor            5
# 2        Channel Master Titan 2 Antenna Preamplifier            5
# 3  LIMTECH Wall charger + USB Hotsync & Charging ...            1
# 4     Skullcandy Air Raid Portable Bluetooth Speaker            5
#
#    helpful_votes  total_votes verified_purchase  \
# 0              0            0                 Y
# 1              0            0                 Y
# 2              1            1                 Y
# 3              0            0                 Y
# 4              1            1                 Y
#
#                  review_headline  \
# 0                     Five Stars
# 1       It works as advertising.
# 2                     Five Stars
# 3                       One Star
# 4  Overall pleased with the item
#
#                                          review_body review_date  helpfulness  \
# 0                                      As described.  2015-08-31          0.0
# 1                           It works as advertising.  2015-08-31          0.0
# 2                                        Works pissa  2015-08-31          1.0
# 3                               Did not work at all.  2015-08-31          0.0
# 4  Works well. Bass is somewhat lacking but is pr...  2015-08-31          1.0
#
#                                     review_full_text  review_length
# 0                           Five Stars As described.             24
# 1  It works as advertising. It works as advertising.             49
# 2                             Five Stars Works pissa             22
# 3                      One Star Did not work at all.             29
# 4  Overall pleased with the item Works well. Bass...            113

# %% [markdown]
# #### Solution 1. No filtering.
# The simplest idea is to not filter anything and just save all required data as it is.

# %%
os.makedirs('../data/processed', exist_ok=True) 

df_personalized[['customer_id', 'product_id', 'star_rating']].to_csv('../data/processed/unfiltered_personalized.csv', index=False)

# %% [markdown]
# #### Solution 2. Basic filtering.
#
# Second idea is to apply some basic filters:
# 1. All reviews with given star rating `3` will be removes. This is a common practice in recommendation system as review `3` has ambiguous nature.
# 2. We will consider only reviews that are considered `helpfull` by other users. This should remove spam reviews and provide more clear and honest understanding of products we are working with. In this case `helpfulness` is considered as `helpful_votes` / `total_votes`. And where this value will exeed 50%, we will count them as `helpfull`.
# 3. For a reason of a doubt we will not trust any unverified purchases.

# %%
df_filtered = df_personalized[(df_personalized['star_rating'] != 3) & (df_personalized['total_votes'] > 0) & (df_personalized['helpfulness'] > 0.5) & (df_personalized['verified_purchase'] == 'Y')]
df_filtered
# Out:
#          customer_id       review_id  product_id  product_parent  \
# 2           12338275  R1P4RW1R9FDPEE  B000GGKOG8       614448099
# 4           23732619  R372S58V6D11AT  B00JOQIO6S       308169188
# 5           21257820  R1A4514XOYI1PD  B008NCD2LG       976385982
# 18          47386264  R1WI5NISM6GAUG  B0045EJY90       892920832
# 19          13000908  R27F4OF4BIA4LU  B003BT6BM8       631236454
# ...              ...             ...         ...             ...
# 3090919     51816404    RE2BZ5R2WNSN  B00000J3NE       184603412
# 3090923     52708254  R2AN3ZV5E3ALB5  B00000J4C9        83670990
# 3090928     52476206  R1J16TEDOYCZTN  B00000J4FW       296815603
# 3090931     52980656   RGHZIK8D6X7QR  B00000JFHW       931077461
# 3090998     53095133  R200I3TSX0SHBK  B00000J4FQ       997289830
#
#                                              product_title  star_rating  \
# 2              Channel Master Titan 2 Antenna Preamplifier            5
# 4           Skullcandy Air Raid Portable Bluetooth Speaker            5
# 5        Pioneer SP-BS22-LR Andrew Jones Designed Books...            5
# 18       TEAC CD-P650-B Compact Disc Player with USB an...            2
# 19                   Philips SHS8100/28 Earhook Headphones            2
# ...                                                    ...          ...
# 3090919  Sharp MDMT821 Ultra-Thin Minidisc Player/Recorder            5
# 3090923  Koss PP257 Water-Resistant Sports Armband Digi...            1
# 3090928  Sharp CDC472 Pro Logic Home Theater System (Di...            4
# 3090931  Harman Kardon TC-1000 Take Control System Cont...            5
# 3090998              JVC RCQN1 Compact Portable CD Boombox            5
#
#          helpful_votes  total_votes verified_purchase  \
# 2                    1            1                 Y
# 4                    1            1                 Y
# 5                    1            1                 Y
# 18                   4            5                 Y
# 19                   1            1                 Y
# ...                ...          ...               ...
# 3090919             69           72                 Y
# 3090923             18           19                 Y
# 3090928             30           31                 Y
# 3090931             11           14                 Y
# 3090998             10           11                 Y
#
#                                            review_headline  \
# 2                                               Five Stars
# 4                            Overall pleased with the item
# 5                                               Five Stars
# 18        It does not copy CD-R s to USB as advertised ...
# 19       Did not last long, Stop working within a year ...
# ...                                                    ...
# 3090919                             Get one...it is great!
# 3090923                               Really bad reception
# 3090928      Overall a good combo of features for price...
# 3090931                              My Wifes Favorite Toy
# 3090998                Sounds great, but it sure is homely
#
#                                                review_body review_date  \
# 2                                              Works pissa  2015-08-31
# 4        Works well. Bass is somewhat lacking but is pr...  2015-08-31
# 5        The quality on these speakers is insanely good...  2015-08-31
# 18       It does not copy CD-R s to USB as advertised. ...  2015-08-31
# 19         Did not last long,  Stop working within a year.  2015-08-31
# ...                                                    ...         ...
# 3090919  I purchased a Sony R55 a few months ago and re...  1999-08-03
# 3090923  Constant static with nearly all radio stations...  1999-07-30
# 3090928  I'm looking into systems to replace a stereo t...  1999-07-27
# 3090931  This device is a G*d send.We had 8 different r...  1999-07-26
# 3090998  I just received our JVC box last night-- we pu...  1999-07-07
#
#          helpfulness                                   review_full_text  \
# 2           1.000000                             Five Stars Works pissa
# 4           1.000000  Overall pleased with the item Works well. Bass...
# 5           1.000000  Five Stars The quality on these speakers is in...
# 18          0.800000  It does not copy CD-R s to USB as advertised ....
# 19          1.000000  Did not last long, Stop working within a year ...
# ...              ...                                                ...
# 3090919     0.958333  Get one...it is great! I purchased a Sony R55 ...
# 3090923     0.947368  Really bad reception Constant static with near...
# 3090928     0.967742  Overall a good combo of features for price... ...
# 3090931     0.785714  My Wifes Favorite Toy This device is a G*d sen...
# 3090998     0.909091  Sounds great, but it sure is homely I just rec...
#
#          review_length
# 2                   22
# 4                  113
# 5                  125
# 18                 348
# 19                  97
# ...                ...
# 3090919            657
# 3090923            146
# 3090928            324
# 3090931            330
# 3090998            415
#
# [561980 rows x 15 columns]

# %% [markdown]
# To proove that the filtering above did not change distributions, we can see how star rating deviates.
#
# Even thought we only left 18.2% of rows, we have almost identicall mean with a bit higher std (which is expected as we removed all revies with 3 stars).

# %%
df_filtered.star_rating.describe()
# Out:
# count    561980.000000
# mean          4.045016
# std           1.462215
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: star_rating, dtype: float64

# %%
df.star_rating.describe()
# Out:
# count    3.090810e+06
# mean     4.035417e+00
# std      1.387458e+00
# min      1.000000e+00
# 25%      3.000000e+00
# 50%      5.000000e+00
# 75%      5.000000e+00
# max      5.000000e+00
# Name: star_rating, dtype: float64

# %%
os.makedirs('../data/processed', exist_ok=True) 

df_filtered[['customer_id', 'product_id', 'star_rating']].to_csv('../data/processed/filtered_simple_personalized.csv')

# %% [markdown]
# ### Solution 3. Text verification.
#
# This idea is based on assumption that some reviews may provide inappropriate star rating that do not actually correspond to the review comment. In order to check it, we decided to take bert-like model that could analyze. We will also apply this technique to already filtered dataframe, as i takes 4 hours to run on whole, and only 1 hour to run on filtered.

# %%
from transformers import AutoTokenizer, AutoConfig, pipeline

distilled_student_sentiment_classifier = pipeline(
    model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", 
    top_k=None,
    truncation=True,
    device=0,
)

# %%
from tqdm.auto import tqdm

pos_scores = []
neu_scores = []
neg_scores = []

for idx, row in tqdm(df_filtered.iterrows(), total=df_filtered.shape[0]):
    
    ######### REMOVE THIS IF YOU WANT TO RUN OUR CODE #########
    ######### it's is here to show approximate time to inference #########
    if idx > 1000:
        break
    ######### END OF REMOVE #########
    
        
    text = row["review_full_text"]
    out = distilled_student_sentiment_classifier(text)[0]
    
    for sentiment in out:
        if sentiment["label"] == "positive":
            pos_scores.append(sentiment["score"])

        if sentiment["label"] == "neutral":
            neu_scores.append(sentiment["score"])

        if sentiment["label"] == "negative":
            neg_scores.append(sentiment["score"])
# Out:
#   0%|          | 0/561980 [00:00<?, ?it/s]

# %%
df_filtered["positive_score"] = pos_scores
df_filtered["neutral_score"] = neu_scores
df_filtered["negative_score"] = neg_scores

# %%
os.makedirs('../data/processed', exist_ok=True) 

df_filtered.to_csv("../data/processed/df_filtered_with_scores.csv", index=False)

# %%
# apply with new values additional preprocessing
df_scored = pd.read_csv('../data/processed/df_filtered_with_scores.csv')
df_scored.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     12338275  R1P4RW1R9FDPEE  B000GGKOG8       614448099
# 1          US     23732619  R372S58V6D11AT  B00JOQIO6S       308169188
# 2          US     21257820  R1A4514XOYI1PD  B008NCD2LG       976385982
# 3          US     47386264  R1WI5NISM6GAUG  B0045EJY90       892920832
# 4          US     13000908  R27F4OF4BIA4LU  B003BT6BM8       631236454
#
#                                        product_title product_category  \
# 0        Channel Master Titan 2 Antenna Preamplifier      Electronics
# 1     Skullcandy Air Raid Portable Bluetooth Speaker      Electronics
# 2  Pioneer SP-BS22-LR Andrew Jones Designed Books...      Electronics
# 3  TEAC CD-P650-B Compact Disc Player with USB an...      Electronics
# 4              Philips SHS8100/28 Earhook Headphones      Electronics
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            5              1            1    N                 Y
# 1            5              1            1    N                 Y
# 2            5              1            1    N                 Y
# 3            2              4            5    N                 Y
# 4            2              1            1    N                 Y
#
#                                      review_headline  \
# 0                                         Five Stars
# 1                      Overall pleased with the item
# 2                                         Five Stars
# 3   It does not copy CD-R s to USB as advertised ...
# 4  Did not last long, Stop working within a year ...
#
#                                          review_body review_date  \
# 0                                        Works pissa  2015-08-31
# 1  Works well. Bass is somewhat lacking but is pr...  2015-08-31
# 2  The quality on these speakers is insanely good...  2015-08-31
# 3  It does not copy CD-R s to USB as advertised. ...  2015-08-31
# 4    Did not last long,  Stop working within a year.  2015-08-31
#
#                                     review_full_text  positive_score  \
# 0                             Five Stars Works pissa        0.633590
# 1  Overall pleased with the item Works well. Bass...        0.645478
# 2  Five Stars The quality on these speakers is in...        0.863384
# 3  It does not copy CD-R s to USB as advertised ....        0.189209
# 4  Did not last long, Stop working within a year ...        0.360234
#
#    neutral_score  negative_score
# 0       0.188220        0.178190
# 1       0.196312        0.158210
# 2       0.101171        0.035446
# 3       0.427809        0.382981
# 4       0.313394        0.326372

# %%
# let's look at distributions
df_scored.positive_score.describe(), df_scored.neutral_score.describe(), df_scored.negative_score.describe()
# Out:
# (count    561980.000000
#  mean          0.562636
#  std           0.298186
#  min           0.003431
#  25%           0.296404
#  50%           0.593064
#  75%           0.842058
#  max           0.996073
#  Name: positive_score, dtype: float64,
#  count    561980.000000
#  mean          0.169324
#  std           0.108059
#  min           0.002360
#  25%           0.081750
#  50%           0.157580
#  75%           0.238560
#  max           0.762785
#  Name: neutral_score, dtype: float64,
#  count    561980.000000
#  mean          0.268040
#  std           0.238484
#  min           0.000868
#  25%           0.057454
#  50%           0.204236
#  75%           0.427561
#  max           0.986743
#  Name: negative_score, dtype: float64)

# %%
df_scored[(df_scored.star_rating > 3) & (df_scored.negative_score > 0.9)].head()
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 2844           US     46085619  R12JEGPXV1HAO9  B00E952W3A       444188034
# 5433           US       118523  R2PY15IIGOZ9G7  B00OHHG768       720920423
# 5647           US     48402755  R155JEV23CFZC9  B00ILCRZRK       262655934
# 7492           US     33853810  R3FHT7MAC46WS2  B004ZKXY7C       836118938
# 11309          US     21509517  R2F7TJLI04COJO  B00PVMNTAA       363270033
#
#                                            product_title product_category  \
# 2844                     Zipbuds Zipbuds Pro Mic Earbuds      Electronics
# 5433   C&E Mini HDMI 3-In 1-Out (Hdmi V1.3) Intellige...      Electronics
# 5647   Yamaha RX-V577 7.2-channel Wi-Fi Network AV Re...      Electronics
# 7492   Sharp SPC800 Quartz Analog Twin Bell Alarm Clo...      Electronics
# 11309  GENERIC AA59-00766A RMCTPF Smart Hub Audio sou...      Electronics
#
#        star_rating  helpful_votes  total_votes vine verified_purchase  \
# 2844             4              1            1    N                 Y
# 5433             5              1            1    N                 Y
# 5647             4              3            4    N                 Y
# 7492             4              1            1    N                 Y
# 11309            5              1            1    N                 Y
#
#                                          review_headline  \
# 2844   The chord creates just a bit more noise than I...
# 5433   i really hate that our tv only came with limit...
# 5647                Awesome except AirPlay vulnerability
# 7492                               My daughters hate it.
# 11309  Great replacement for my dropped once to often...
#
#                                              review_body review_date  \
# 2844   I've used these for just over a month and ther...  2015-08-25
# 5433   i really hate that our tv only came with limit...  2015-08-18
# 5647   Only bad thing so far it's inability to block ...  2015-08-18
# 7492   My daughters hate it. It is loud and obnoxious...  2015-08-13
# 11309  Great replacement for my dropped once to often...  2015-08-04
#
#                                         review_full_text  positive_score  \
# 2844   The chord creates just a bit more noise than I...        0.011376
# 5433   i really hate that our tv only came with limit...        0.044456
# 5647   Awesome except AirPlay vulnerability Only bad ...        0.023146
# 7492   My daughters hate it. My daughters hate it. It...        0.008132
# 11309  Great replacement for my dropped once to often...        0.026462
#
#        neutral_score  negative_score
# 2844        0.051220        0.937404
# 5433        0.023469        0.932075
# 5647        0.044035        0.932818
# 7492        0.017300        0.974568
# 11309       0.065254        0.908284

# %%
df_scored[(df_scored.star_rating < 3) & (df_scored.positive_score > 0.9)].head()
# Out:
#      marketplace  customer_id       review_id  product_id  product_parent  \
# 207           US      2602418  R2LUDAE6F9SHPA  B00M9LBMC8       210220996
# 363           US     10819127   RXHYP037YFZ6S  B00NS3MRKC       677514508
# 1320          US      2885890  R1EMHOAO2ATP8T  B00EO8L5TE       455429670
# 2104          US     22000601  R318JY1HK01DW1  B0058O8H30       993527082
# 3543          US     39062322  R3OPKVB1YZ13OB  B00MXCIK32       823852970
#
#                                           product_title product_category  \
# 207   Symphonized NRG Premium Genuine Wood In-ear No...      Electronics
# 363       FiiO X1 High Resolution Lossless Music Player      Electronics
# 1320           ClearTV X-72 HDTV Digital Indoor Antenna      Electronics
# 2104     Atlantic 38435720 Oskar 464 Media Wall Unit P2      Electronics
# 3543  Panasonic eneloop pro AA High Capacity New Ni-...      Electronics
#
#       star_rating  helpful_votes  total_votes vine verified_purchase  \
# 207             1              1            1    N                 Y
# 363             2              3            3    N                 Y
# 1320            2              1            1    N                 Y
# 2104            2              1            1    N                 Y
# 3543            1             28           37    N                 Y
#
#                                         review_headline  \
# 207   The sound was pretty good until one of the spe...
# 363                                 Good when it worked
# 1320                     Rabbit ears are twice as good!
# 2104  I will say that the design is good and the ver...
# 3543                            It's great and the best
#
#                                             review_body review_date  \
# 207   The sound was pretty good until one of the spe...  2015-08-31
# 363   Was awesome when it worked.<br />Got a blue sc...  2015-08-31
# 1320         Do Not Buy! Rabbit ears are twice as good!  2015-08-28
# 2104  The cams that hold the unit together were the ...  2015-08-26
# 3543  It's great and the best. Nothing wrong with th...  2015-08-23
#
#                                        review_full_text  positive_score  \
# 207   The sound was pretty good until one of the spe...        0.925921
# 363   Good when it worked Was awesome when it worked...        0.908742
# 1320  Rabbit ears are twice as good! Do Not Buy! Rab...        0.947384
# 2104  I will say that the design is good and the ver...        0.925071
# 3543  It's great and the best It's great and the bes...        0.944180
#
#       neutral_score  negative_score
# 207        0.052600        0.021479
# 363        0.050540        0.040718
# 1320       0.036779        0.015837
# 2104       0.040925        0.034004
# 3543       0.050998        0.004821

# %% [markdown]
# After a bit further analysis, we noticed that reviews with rating `4` and `negative_score` greater than 0.9 have interesting dynamic. They are positive (judging by rating), but comments actually describes how bad product is. For this inconsistency we decided to filter such rows as they may be misleading.
#
# We did not find such correlations with ratings 5, 1 and 2. Which is pretty interesting for us.
#
# It is also worth mentioning that model we used have some FPs and TNs which may skew our real computations.

# %%
df_without_outliers = df_scored[~((df_scored.star_rating == 4) & (df_scored.negative_score > 0.9))]
df_without_outliers.shape
# Out:
# (561932, 19)

# %%
df_without_outliers.star_rating.describe()
# Out:
# count    561932.000000
# mean          4.045020
# std           1.462277
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: star_rating, dtype: float64

# %%
os.makedirs('../data/processed', exist_ok=True) 

df_without_outliers[['customer_id', 'product_id', 'star_rating']].to_csv("../data/processed/df_filtered_removed_outliers.csv", index=False)

# %% [markdown]
# Here we remove users that have too few ratings

# %%
import pandas as pd
df = pd.read_csv("../data/processed/df_filtered_removed_outliers.csv")
counts = df['customer_id'].value_counts()

ids_to_drop = counts[counts < 3].index
filtered_df = df[~df['customer_id'].isin(ids_to_drop)]
len(filtered_df), len(df)
filtered_df.to_csv("../data/processed/df_no_cold_start.csv")
